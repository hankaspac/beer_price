# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.utils.data import random_split
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
from sklearn.model_selection import train_test_split
from PIL import Image
from torchsummary import summary

# %%
img_size = 112
my_batch_size = 32
splt_num = 0.80

# %%
labels_map = {
    0: 'daura: 55dkk', 
    1: 'ginger_beer_without: 45dkk',
    2: 'blanc: 45dkk', 
    3: 'fynsk_foraar: 45dkk', 
    4: 'mokai: 45dkk',
    5: 'punk_ipa_without: 55dkk', 
    6: 'ginger_beer: 55dkk', 
    7: 'thor_pilsner: 28dkk', 
    8: 'thor_classic: 34dkk', 
    9: 'odense_classic: 34dkk', 
    10: 'odense_pilsner: 28dkk', 
    11: 'hazy_jane: 55dkk', 
    12: 'grimbergen_blonde: 45dkk', 
    13: 'grimbergen_double: 45dkk', 
    14: 's_smith_chocolade: 55dkk', 
    15: 's_smith_apricot: 55dkk', 
    16: 'trapist_8: 55dkk', 
    17: 's_smith_stout: 55dkk', 
    18: 'mirinda: 28dkk', 
    19: '7_up: 28dkk', 
    20: 'schweps: 28dkk', 
    21: 'tonic: 28dkk', 
    22: 'tuborg_guld: 40dkk', 
    23: 'blaaa_thor: 40dkk', 
    24: 'ale_nr_16: 40dkk', 
    25: 'ludwig_dunkel: 65dkk', 
    26: 'ludwig_weiss: 65dkk', 
    27: 'sierra_pale_ale: 55dkk', 
    28: 'dansk_vand: 34dkk', 
    29: 'dansk_vand_citron: 34dkk', 
    30: 'blanc_without: 45dkk', 
    31: 'heineken_without: 34dkk', 
    32: 'royal_classic_without: 34dkk', 
    33: 'royal_pilsner_without: 34dkk', 
    34: 'pepsi: 28dkk', 
    35: 'pepsi_max: 28dkk', 
    36: 'ceres_top: 28dkk', 
    37: 'tuborg_groen: 28dkk', 
    38: 'somersby: 45dkk', 
    39: 's_smith_cider: 55dkk', 
    40: 'cocio: 34dkk', 
    41: 'aeble_most: 34dkk', 
    42: 'appelsin_juice: 34dkk', 
    43: 'hyldeblomst_drik: 34dkk', 
    44: 'limfjords_porter: 45dkk', 
    45: 'sierra_torpedo: 45dkk', 
    46: 'tuborg_juleoel: 40dkk', 
    47: 'albani_juleoel: 40dkk'
}

# %%
class MyImageDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_size=(300, 400), target_transform=None):
        self.img_labels = pd.read_excel(annotations_file)
        self.img_dir = img_dir
        self.transform = transform
        self.target_size = target_size
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 2])
        image = Image.open(img_path)
        
        image = image.resize(self.target_size)
        label = self.img_labels.iloc[idx, 0]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
my_transform = transforms.Compose([transforms.Resize((img_size, img_size)), transforms.ToTensor()])

# %%
my_set = MyImageDataset('my_data_changed_labels.xlsx', 'imgs_out/', transform=my_transform)

# %%
print(len(my_set))
print(type(my_set))
# Out:
# 499
# <class '__main__.MyImageDataset'>

# %%
def split_data(dataset):
    train_size = int(splt_num * len(dataset))
    test_size = len(dataset) - train_size
    
    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])
    return train_dataset, test_dataset

# %%
train_set, test_set = split_data(my_set)

# %%
print(len(train_set))
print(len(test_set))
# Out:
# 399
# 100

# %%
train_dataloader = DataLoader(train_set, batch_size=my_batch_size, shuffle=True)
test_dataloader = DataLoader(test_set, batch_size=my_batch_size, shuffle=True)

# %%
print(type(train_dataloader))
print(type(test_dataloader))
# Out:
# <class 'torch.utils.data.dataloader.DataLoader'>
# <class 'torch.utils.data.dataloader.DataLoader'>

# %%
for X, y in train_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Type of y: {type(y)}")
    

    fig, axes = plt.subplots(1, 6, figsize=(10, 10))
    axes = axes.flatten()

    for i in range(6):
        img = np.transpose(X[i].squeeze(0), (1, 2, 0))
        
        axes[i].imshow(img)
        axes[i].set_title(f"{y[i]}\n{labels_map[i]}")
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([32, 3, 112, 112])
# Type of y: <class 'torch.Tensor'>

# %%
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_dataloader), size=(1,)).item()
    img, label = train_dataloader.dataset[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(f'{label} : \n {labels_map[label]}')
    plt.axis("off")
    plt.imshow(np.transpose(img.numpy(), (1, 2, 0)))
plt.show()

# %%
device = (
    "cuda" if torch.cuda.is_available()
     else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu  = nn.ReLU(inplace=True)
        self.pool  = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.flatten = nn.Flatten()
        self.fc1   = nn.Linear(img_size*img_size*128, 128) #w*h*out-layers from conv layer
        self.fc2   = nn.Linear(128, 64)
        self.fc3   = nn.Linear(64, 48)

    def forward(self, x):
      x = self.conv1(x) 
      x = self.relu(x)
      x = self.conv2(x)
      x = self.relu(x)
      x = self.conv3(x)
      x = self.relu(x)
      x = self.flatten(x)
      x = self.fc1(x)
      x = self.relu(x)
      x = self.fc2(x)
      x = self.relu(x)
      x = self.fc3(x)
      return x


model = MyModel().to(device)
print(model)
# Out:
# MyModel(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu): ReLU(inplace=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=1605632, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=48, bias=True)
# )

# %%
summary(model, input_size=(3, 112, 112), device=device)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            896
# ├─Conv2d: 1-2                            18,496
# ├─Conv2d: 1-3                            73,856
# ├─ReLU: 1-4                              --
# ├─MaxPool2d: 1-5                         --
# ├─Flatten: 1-6                           --
# ├─Linear: 1-7                            205,521,024
# ├─Linear: 1-8                            8,256
# ├─Linear: 1-9                            3,120
# =================================================================
# Total params: 205,625,648
# Trainable params: 205,625,648
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            896
# ├─Conv2d: 1-2                            18,496
# ├─Conv2d: 1-3                            73,856
# ├─ReLU: 1-4                              --
# ├─MaxPool2d: 1-5                         --
# ├─Flatten: 1-6                           --
# ├─Linear: 1-7                            205,521,024
# ├─Linear: 1-8                            8,256
# ├─Linear: 1-9                            3,120
# =================================================================
# Total params: 205,625,648
# Trainable params: 205,625,648
# Non-trainable params: 0
# =================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    total_loss, correct = 0, 0  # Track the total loss for the epoch

    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        pred = model(X)
        
        loss = loss_fn(pred, y)
        total_loss += loss.item()  # Accumulate loss

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        # Calculate accuracy
        correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    avg_loss = total_loss / len(dataloader)  # Calculate average loss for the epoch
    avg_accuracy = correct / size

    train_losses.append(avg_loss)  # Store the average loss for the epoch
    train_accuracies.append(avg_accuracy) # Store the average accuracy for the epoch

    print(f"Train loss: {avg_loss:>7f}, Accuracy: {100*(avg_accuracy):>0.1f}%")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    test_losses.append(test_loss)  # Store the test loss for the epoch
    test_accuracies.append(correct)

    print(f"Test Error: \n Avg loss: {test_loss:>8f}, Accuracy: {100*(correct):>0.1f}% \n")

# %%
epochs = 150
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 3.880691  [   32/  399]
# Train loss: 3.874518, Accuracy: 1.8%
# Test Error:
#  Avg loss: 3.874900, Accuracy: 6.0%
#
# Epoch 2
# -------------------------------
# loss: 3.855546  [   32/  399]
# Train loss: 3.871779, Accuracy: 2.5%
# Test Error:
#  Avg loss: 3.863878, Accuracy: 6.0%
#
# Epoch 3
# -------------------------------
# loss: 3.879572  [   32/  399]
# Train loss: 3.873667, Accuracy: 2.3%
# Test Error:
#  Avg loss: 3.873890, Accuracy: 6.0%
#
# Epoch 4
# -------------------------------
# loss: 3.880877  [   32/  399]
# Train loss: 3.872668, Accuracy: 1.8%
# Test Error:
#  Avg loss: 3.887831, Accuracy: 6.0%
#
# Epoch 5
# -------------------------------
# loss: 3.865980  [   32/  399]
# Train loss: 3.872199, Accuracy: 2.8%
# Test Error:
#  Avg loss: 3.863808, Accuracy: 6.0%
#
# Epoch 6
# -------------------------------
# loss: 3.851766  [   32/  399]
# Train loss: 3.872423, Accuracy: 1.8%
# Test Error:
#  Avg loss: 3.881631, Accuracy: 6.0%
#
# Epoch 7
# -------------------------------
# loss: 3.887753  [   32/  399]
# Train loss: 3.871569, Accuracy: 2.5%
# Test Error:
#  Avg loss: 3.876334, Accuracy: 6.0%
#
# Epoch 8
# -------------------------------
# loss: 3.879216  [   32/  399]
# Train loss: 3.869071, Accuracy: 2.3%
# Test Error:
#  Avg loss: 3.866013, Accuracy: 6.0%
#
# Epoch 9
# -------------------------------
# loss: 3.888299  [   32/  399]
# Train loss: 3.867554, Accuracy: 1.8%
# Test Error:
#  Avg loss: 3.869715, Accuracy: 6.0%
#
# Epoch 10
# -------------------------------
# loss: 3.859125  [   32/  399]
# Train loss: 3.869794, Accuracy: 1.8%
# Test Error:
#  Avg loss: 3.885350, Accuracy: 6.0%
#
# Epoch 11
# -------------------------------
# loss: 3.858944  [   32/  399]
# Train loss: 3.869724, Accuracy: 3.5%
# Test Error:
#  Avg loss: 3.869269, Accuracy: 7.0%
#
# Epoch 12
# -------------------------------
# loss: 3.879901  [   32/  399]
# Train loss: 3.867765, Accuracy: 3.5%
# Test Error:
#  Avg loss: 3.876152, Accuracy: 9.0%
#
# Epoch 13
# -------------------------------
# loss: 3.852120  [   32/  399]
# Train loss: 3.867217, Accuracy: 5.5%
# Test Error:
#  Avg loss: 3.882428, Accuracy: 5.0%
#
# Epoch 14
# -------------------------------
# loss: 3.867706  [   32/  399]
# Train loss: 3.865585, Accuracy: 5.5%
# Test Error:
#  Avg loss: 3.879376, Accuracy: 10.0%
#
# Epoch 15
# -------------------------------
# loss: 3.875917  [   32/  399]
# Train loss: 3.867283, Accuracy: 3.5%
# Test Error:
#  Avg loss: 3.878632, Accuracy: 3.0%
#
# Epoch 16
# -------------------------------
# loss: 3.865944  [   32/  399]
# Train loss: 3.864673, Accuracy: 4.5%
# Test Error:
#  Avg loss: 3.878357, Accuracy: 4.0%
#
# Epoch 17
# -------------------------------
# loss: 3.857346  [   32/  399]
# Train loss: 3.865361, Accuracy: 4.0%
# Test Error:
#  Avg loss: 3.900570, Accuracy: 3.0%
#
# Epoch 18
# -------------------------------
# loss: 3.862923  [   32/  399]
# Train loss: 3.863123, Accuracy: 2.5%
# Test Error:
#  Avg loss: 3.885863, Accuracy: 1.0%
#
# Epoch 19
# -------------------------------
# loss: 3.846153  [   32/  399]
# Train loss: 3.865457, Accuracy: 2.8%
# Test Error:
#  Avg loss: 3.883531, Accuracy: 1.0%
#
# Epoch 20
# -------------------------------
# loss: 3.846379  [   32/  399]
# Train loss: 3.862643, Accuracy: 2.3%
# Test Error:
#  Avg loss: 3.872539, Accuracy: 1.0%
#
# Epoch 21
# -------------------------------
# loss: 3.854144  [   32/  399]
# Train loss: 3.861917, Accuracy: 3.3%
# Test Error:
#  Avg loss: 3.884299, Accuracy: 1.0%
#
# Epoch 22
# -------------------------------
# loss: 3.856094  [   32/  399]
# Train loss: 3.862702, Accuracy: 2.3%
# Test Error:
#  Avg loss: 3.891731, Accuracy: 2.0%
#
# Epoch 23
# -------------------------------
# loss: 3.877256  [   32/  399]
# Train loss: 3.862546, Accuracy: 2.8%
# Test Error:
#  Avg loss: 3.907640, Accuracy: 3.0%
#
# Epoch 24
# -------------------------------
# loss: 3.855949  [   32/  399]
# Train loss: 3.860732, Accuracy: 4.3%
# Test Error:
#  Avg loss: 3.879971, Accuracy: 1.0%
#
# Epoch 25
# -------------------------------
# loss: 3.852652  [   32/  399]
# Train loss: 3.860979, Accuracy: 3.8%
# Test Error:
#  Avg loss: 3.894411, Accuracy: 2.0%
#
# Epoch 26
# -------------------------------
# loss: 3.854746  [   32/  399]
# Train loss: 3.858494, Accuracy: 5.0%
# Test Error:
#  Avg loss: 3.898495, Accuracy: 0.0%
#
# Epoch 27
# -------------------------------
# loss: 3.899074  [   32/  399]
# Train loss: 3.858954, Accuracy: 4.3%
# Test Error:
#  Avg loss: 3.901157, Accuracy: 4.0%
#
# Epoch 28
# -------------------------------
# loss: 3.885803  [   32/  399]
# Train loss: 3.857412, Accuracy: 4.3%
# Test Error:
#  Avg loss: 3.902001, Accuracy: 4.0%
#
# Epoch 29
# -------------------------------
# loss: 3.851546  [   32/  399]
# Train loss: 3.857341, Accuracy: 4.3%
# Test Error:
#  Avg loss: 3.886486, Accuracy: 4.0%
#
# Epoch 30
# -------------------------------
# loss: 3.873837  [   32/  399]
# Train loss: 3.858142, Accuracy: 4.0%
# Test Error:
#  Avg loss: 3.907714, Accuracy: 4.0%
#
# Epoch 31
# -------------------------------
# loss: 3.864420  [   32/  399]
# Train loss: 3.859275, Accuracy: 3.5%
# Test Error:
#  Avg loss: 3.908213, Accuracy: 4.0%
#
# Epoch 32
# -------------------------------
# loss: 3.851958  [   32/  399]
# Train loss: 3.856541, Accuracy: 4.3%
# Test Error:
#  Avg loss: 3.902570, Accuracy: 4.0%
#
# Epoch 33
# -------------------------------
# loss: 3.869983  [   32/  399]
# Train loss: 3.856825, Accuracy: 4.0%
# Test Error:
#  Avg loss: 3.893936, Accuracy: 4.0%
#
# Epoch 34
# -------------------------------
# loss: 3.854749  [   32/  399]
# Train loss: 3.856359, Accuracy: 4.0%
# Test Error:
#  Avg loss: 3.916544, Accuracy: 4.0%
#
# Epoch 35
# -------------------------------
# loss: 3.849575  [   32/  399]
# Train loss: 3.852796, Accuracy: 4.3%
# Test Error:
#  Avg loss: 3.897525, Accuracy: 4.0%
#
# Epoch 36
# -------------------------------
# loss: 3.826716  [   32/  399]
# Train loss: 3.852422, Accuracy: 4.8%
# Test Error:
#  Avg loss: 3.903606, Accuracy: 4.0%
#
# Epoch 37
# -------------------------------
# loss: 3.885730  [   32/  399]
# Train loss: 3.851068, Accuracy: 5.0%
# Test Error:
#  Avg loss: 3.892434, Accuracy: 4.0%
#
# Epoch 38
# -------------------------------
# loss: 3.860243  [   32/  399]
# Train loss: 3.851971, Accuracy: 4.8%
# Test Error:
#  Avg loss: 3.913015, Accuracy: 4.0%
#
# Epoch 39
# -------------------------------
# loss: 3.893664  [   32/  399]
# Train loss: 3.850527, Accuracy: 5.3%
# Test Error:
#  Avg loss: 3.900215, Accuracy: 4.0%
#
# Epoch 40
# -------------------------------
# loss: 3.811090  [   32/  399]
# Train loss: 3.850503, Accuracy: 5.3%
# Test Error:
#  Avg loss: 3.901180, Accuracy: 4.0%
#
# Epoch 41
# -------------------------------
# loss: 3.871585  [   32/  399]
# Train loss: 3.848614, Accuracy: 3.8%
# Test Error:
#  Avg loss: 3.916778, Accuracy: 4.0%
#
# Epoch 42
# -------------------------------
# loss: 3.844445  [   32/  399]
# Train loss: 3.849679, Accuracy: 4.8%
# Test Error:
#  Avg loss: 3.928181, Accuracy: 4.0%
#
# Epoch 43
# -------------------------------
# loss: 3.892861  [   32/  399]
# Train loss: 3.850629, Accuracy: 5.3%
# Test Error:
#  Avg loss: 3.923491, Accuracy: 4.0%
#
# Epoch 44
# -------------------------------
# loss: 3.899636  [   32/  399]
# Train loss: 3.846463, Accuracy: 5.3%
# Test Error:
#  Avg loss: 3.912732, Accuracy: 4.0%
#
# Epoch 45
# -------------------------------
# loss: 3.864362  [   32/  399]
# Train loss: 3.846842, Accuracy: 4.8%
# Test Error:
#  Avg loss: 3.919985, Accuracy: 2.0%
#
# Epoch 46
# -------------------------------
# loss: 3.863497  [   32/  399]
# Train loss: 3.848322, Accuracy: 5.3%
# Test Error:
#  Avg loss: 3.929710, Accuracy: 2.0%
#
# Epoch 47
# -------------------------------
# loss: 3.815801  [   32/  399]
# Train loss: 3.845862, Accuracy: 5.8%
# Test Error:
#  Avg loss: 3.911237, Accuracy: 1.0%
#
# Epoch 48
# -------------------------------
# loss: 3.821660  [   32/  399]
# Train loss: 3.845001, Accuracy: 5.3%
# Test Error:
#  Avg loss: 3.914987, Accuracy: 2.0%
#
# Epoch 49
# -------------------------------
# loss: 3.905218  [   32/  399]
# Train loss: 3.845054, Accuracy: 5.5%
# Test Error:
#  Avg loss: 3.912768, Accuracy: 1.0%
#
# Epoch 50
# -------------------------------
# loss: 3.806746  [   32/  399]
# Train loss: 3.844232, Accuracy: 4.5%
# Test Error:
#  Avg loss: 3.905460, Accuracy: 4.0%
#
# Epoch 51
# -------------------------------
# loss: 3.867945  [   32/  399]
# Train loss: 3.845501, Accuracy: 5.5%
# Test Error:
#  Avg loss: 3.950815, Accuracy: 2.0%
#
# Epoch 52
# -------------------------------
# loss: 3.796551  [   32/  399]
# Train loss: 3.844196, Accuracy: 6.3%
# Test Error:
#  Avg loss: 3.939726, Accuracy: 3.0%
#
# Epoch 53
# -------------------------------
# loss: 3.822587  [   32/  399]
# Train loss: 3.838876, Accuracy: 5.8%
# Test Error:
#  Avg loss: 3.926482, Accuracy: 3.0%
#
# Epoch 54
# -------------------------------
# loss: 3.825778  [   32/  399]
# Train loss: 3.840448, Accuracy: 6.8%
# Test Error:
#  Avg loss: 3.910794, Accuracy: 2.0%
#
# Epoch 55
# -------------------------------
# loss: 3.842652  [   32/  399]
# Train loss: 3.838851, Accuracy: 6.0%
# Test Error:
#  Avg loss: 3.902456, Accuracy: 2.0%
#
# Epoch 56
# -------------------------------
# loss: 3.837532  [   32/  399]
# Train loss: 3.838152, Accuracy: 5.3%
# Test Error:
#  Avg loss: 3.947803, Accuracy: 2.0%
#
# Epoch 57
# -------------------------------
# loss: 3.824411  [   32/  399]
# Train loss: 3.837658, Accuracy: 6.3%
# Test Error:
#  Avg loss: 3.908486, Accuracy: 2.0%
#
# Epoch 58
# -------------------------------
# loss: 3.875062  [   32/  399]
# Train loss: 3.836717, Accuracy: 6.3%
# Test Error:
#  Avg loss: 3.914116, Accuracy: 2.0%
#
# Epoch 59
# -------------------------------
# loss: 3.848178  [   32/  399]
# Train loss: 3.833329, Accuracy: 7.0%
# Test Error:
#  Avg loss: 3.930155, Accuracy: 3.0%
#
# Epoch 60
# -------------------------------
# loss: 3.807899  [   32/  399]
# Train loss: 3.833634, Accuracy: 7.3%
# Test Error:
#  Avg loss: 3.944418, Accuracy: 2.0%
#
# Epoch 61
# -------------------------------
# loss: 3.847376  [   32/  399]
# Train loss: 3.836883, Accuracy: 5.8%
# Test Error:
#  Avg loss: 3.924135, Accuracy: 1.0%
#
# Epoch 62
# -------------------------------
# loss: 3.791848  [   32/  399]
# Train loss: 3.834307, Accuracy: 7.3%
# Test Error:
#  Avg loss: 3.918825, Accuracy: 3.0%
#
# Epoch 63
# -------------------------------
# loss: 3.763031  [   32/  399]
# Train loss: 3.828401, Accuracy: 6.8%
# Test Error:
#  Avg loss: 3.914244, Accuracy: 4.0%
#
# Epoch 64
# -------------------------------
# loss: 3.797386  [   32/  399]
# Train loss: 3.832163, Accuracy: 5.8%
# Test Error:
#  Avg loss: 3.966361, Accuracy: 4.0%
#
# Epoch 65
# -------------------------------
# loss: 3.845762  [   32/  399]
# Train loss: 3.830917, Accuracy: 6.8%
# Test Error:
#  Avg loss: 3.936375, Accuracy: 4.0%
#
# Epoch 66
# -------------------------------
# loss: 3.876114  [   32/  399]
# Train loss: 3.823547, Accuracy: 6.3%
# Test Error:
#  Avg loss: 3.918674, Accuracy: 3.0%
#
# Epoch 67
# -------------------------------
# loss: 3.840654  [   32/  399]
# Train loss: 3.823017, Accuracy: 7.3%
# Test Error:
#  Avg loss: 3.920895, Accuracy: 2.0%
#
# Epoch 68
# -------------------------------
# loss: 3.818329  [   32/  399]
# Train loss: 3.818343, Accuracy: 9.0%
# Test Error:
#  Avg loss: 3.928785, Accuracy: 2.0%
#
# Epoch 69
# -------------------------------
# loss: 3.820094  [   32/  399]
# Train loss: 3.823299, Accuracy: 6.8%
# Test Error:
#  Avg loss: 3.933574, Accuracy: 2.0%
#
# Epoch 70
# -------------------------------
# loss: 3.807218  [   32/  399]
# Train loss: 3.819972, Accuracy: 7.5%
# Test Error:
#  Avg loss: 3.979784, Accuracy: 3.0%
#
# Epoch 71
# -------------------------------
# loss: 3.862739  [   32/  399]
# Train loss: 3.818261, Accuracy: 8.0%
# Test Error:
#  Avg loss: 3.944848, Accuracy: 3.0%
#
# Epoch 72
# -------------------------------
# loss: 3.757321  [   32/  399]
# Train loss: 3.815555, Accuracy: 8.0%
# Test Error:
#  Avg loss: 3.925766, Accuracy: 4.0%
#
# Epoch 73
# -------------------------------
# loss: 3.779826  [   32/  399]
# Train loss: 3.818092, Accuracy: 6.5%
# Test Error:
#  Avg loss: 3.923733, Accuracy: 2.0%
#
# Epoch 74
# -------------------------------
# loss: 3.764404  [   32/  399]
# Train loss: 3.817541, Accuracy: 7.5%
# Test Error:
#  Avg loss: 3.890505, Accuracy: 3.0%
#
# Epoch 75
# -------------------------------
# loss: 3.823526  [   32/  399]
# Train loss: 3.812619, Accuracy: 9.5%
# Test Error:
#  Avg loss: 3.959946, Accuracy: 3.0%
#
# Epoch 76
# -------------------------------
# loss: 3.827300  [   32/  399]
# Train loss: 3.807698, Accuracy: 9.3%
# Test Error:
#  Avg loss: 3.955688, Accuracy: 4.0%
#
# Epoch 77
# -------------------------------
# loss: 3.773982  [   32/  399]
# Train loss: 3.801999, Accuracy: 9.0%
# Test Error:
#  Avg loss: 3.940254, Accuracy: 3.0%
#
# Epoch 78
# -------------------------------
# loss: 3.784546  [   32/  399]
# Train loss: 3.808068, Accuracy: 9.5%
# Test Error:
#  Avg loss: 3.952173, Accuracy: 3.0%
#
# Epoch 79
# -------------------------------
# loss: 3.819891  [   32/  399]
# Train loss: 3.801772, Accuracy: 9.3%
# Test Error:
#  Avg loss: 3.925781, Accuracy: 3.0%
#
# Epoch 80
# -------------------------------
# loss: 3.814778  [   32/  399]
# Train loss: 3.798655, Accuracy: 9.8%
# Test Error:
#  Avg loss: 3.961206, Accuracy: 2.0%
#
# Epoch 81
# -------------------------------
# loss: 3.768349  [   32/  399]
# Train loss: 3.799309, Accuracy: 7.3%
# Test Error:
#  Avg loss: 3.926822, Accuracy: 3.0%
#
# Epoch 82
# -------------------------------
# loss: 3.829758  [   32/  399]
# Train loss: 3.793658, Accuracy: 10.3%
# Test Error:
#  Avg loss: 3.947155, Accuracy: 3.0%
#
# Epoch 83
# -------------------------------
# loss: 3.818012  [   32/  399]
# Train loss: 3.793076, Accuracy: 9.8%
# Test Error:
#  Avg loss: 3.936006, Accuracy: 3.0%
#
# Epoch 84
# -------------------------------
# loss: 3.750215  [   32/  399]
# Train loss: 3.785990, Accuracy: 10.3%
# Test Error:
#  Avg loss: 3.965303, Accuracy: 3.0%
#
# Epoch 85
# -------------------------------
# loss: 3.842132  [   32/  399]
# Train loss: 3.780911, Accuracy: 10.8%
# Test Error:
#  Avg loss: 3.938582, Accuracy: 3.0%
#
# Epoch 86
# -------------------------------
# loss: 3.801955  [   32/  399]
# Train loss: 3.779686, Accuracy: 8.8%
# Test Error:
#  Avg loss: 3.952466, Accuracy: 3.0%
#
# Epoch 87
# -------------------------------
# loss: 3.783495  [   32/  399]
# Train loss: 3.785901, Accuracy: 10.3%
# Test Error:
#  Avg loss: 3.903545, Accuracy: 3.0%
#
# Epoch 88
# -------------------------------
# loss: 3.778115  [   32/  399]
# Train loss: 3.773782, Accuracy: 8.8%
# Test Error:
#  Avg loss: 3.932728, Accuracy: 3.0%
#
# Epoch 89
# -------------------------------
# loss: 3.772478  [   32/  399]
# Train loss: 3.768083, Accuracy: 9.5%
# Test Error:
#  Avg loss: 3.961666, Accuracy: 5.0%
#
# Epoch 90
# -------------------------------
# loss: 3.817867  [   32/  399]
# Train loss: 3.765500, Accuracy: 13.0%
# Test Error:
#  Avg loss: 3.937637, Accuracy: 3.0%
#
# Epoch 91
# -------------------------------
# loss: 3.794236  [   32/  399]
# Train loss: 3.758586, Accuracy: 11.0%
# Test Error:
#  Avg loss: 3.944557, Accuracy: 3.0%
#
# Epoch 92
# -------------------------------
# loss: 3.752853  [   32/  399]
# Train loss: 3.757399, Accuracy: 12.0%
# Test Error:
#  Avg loss: 3.889864, Accuracy: 3.0%
#
# Epoch 93
# -------------------------------
# loss: 3.718867  [   32/  399]
# Train loss: 3.753751, Accuracy: 12.5%
# Test Error:
#  Avg loss: 3.884511, Accuracy: 3.0%
#
# Epoch 94
# -------------------------------
# loss: 3.852903  [   32/  399]
# Train loss: 3.745055, Accuracy: 14.0%
# Test Error:
#  Avg loss: 3.962587, Accuracy: 3.0%
#
# Epoch 95
# -------------------------------
# loss: 3.799721  [   32/  399]
# Train loss: 3.734803, Accuracy: 10.3%
# Test Error:
#  Avg loss: 3.905452, Accuracy: 3.0%
#
# Epoch 96
# -------------------------------
# loss: 3.664694  [   32/  399]
# Train loss: 3.731561, Accuracy: 12.5%
# Test Error:
#  Avg loss: 3.903611, Accuracy: 3.0%
#
# Epoch 97
# -------------------------------
# loss: 3.748608  [   32/  399]
# Train loss: 3.729175, Accuracy: 13.0%
# Test Error:
#  Avg loss: 3.907919, Accuracy: 4.0%
#
# Epoch 98
# -------------------------------
# loss: 3.728980  [   32/  399]
# Train loss: 3.717451, Accuracy: 13.3%
# Test Error:
#  Avg loss: 3.896542, Accuracy: 5.0%
#
# Epoch 99
# -------------------------------
# loss: 3.757097  [   32/  399]
# Train loss: 3.706161, Accuracy: 13.5%
# Test Error:
#  Avg loss: 3.891795, Accuracy: 5.0%
#
# Epoch 100
# -------------------------------
# loss: 3.721825  [   32/  399]
# Train loss: 3.691449, Accuracy: 14.3%
# Test Error:
#  Avg loss: 3.920422, Accuracy: 4.0%
#
# Epoch 101
# -------------------------------
# loss: 3.644392  [   32/  399]
# Train loss: 3.691978, Accuracy: 14.5%
# Test Error:
#  Avg loss: 3.857590, Accuracy: 5.0%
#
# Epoch 102
# -------------------------------
# loss: 3.701653  [   32/  399]
# Train loss: 3.678433, Accuracy: 15.0%
# Test Error:
#  Avg loss: 3.873477, Accuracy: 3.0%
#
# Epoch 103
# -------------------------------
# loss: 3.661395  [   32/  399]
# Train loss: 3.671963, Accuracy: 14.0%
# Test Error:
#  Avg loss: 3.828605, Accuracy: 3.0%
#
# Epoch 104
# -------------------------------
# loss: 3.649512  [   32/  399]
# Train loss: 3.660434, Accuracy: 11.3%
# Test Error:
#  Avg loss: 3.891193, Accuracy: 7.0%
#
# Epoch 105
# -------------------------------
# loss: 3.670489  [   32/  399]
# Train loss: 3.647965, Accuracy: 16.0%
# Test Error:
#  Avg loss: 3.844557, Accuracy: 7.0%
#
# Epoch 106
# -------------------------------
# loss: 3.542361  [   32/  399]
# Train loss: 3.637802, Accuracy: 20.1%
# Test Error:
#  Avg loss: 3.827979, Accuracy: 3.0%
#
# Epoch 107
# -------------------------------
# loss: 3.600957  [   32/  399]
# Train loss: 3.618347, Accuracy: 16.0%
# Test Error:
#  Avg loss: 3.898765, Accuracy: 4.0%
#
# Epoch 108
# -------------------------------
# loss: 3.519054  [   32/  399]
# Train loss: 3.601178, Accuracy: 16.0%
# Test Error:
#  Avg loss: 3.903140, Accuracy: 4.0%
#
# Epoch 109
# -------------------------------
# loss: 3.648963  [   32/  399]
# Train loss: 3.579525, Accuracy: 17.8%
# Test Error:
#  Avg loss: 3.876471, Accuracy: 6.0%
#
# Epoch 110
# -------------------------------
# loss: 3.689917  [   32/  399]
# Train loss: 3.562507, Accuracy: 17.8%
# Test Error:
#  Avg loss: 3.792933, Accuracy: 8.0%
#
# Epoch 111
# -------------------------------
# loss: 3.488167  [   32/  399]
# Train loss: 3.554965, Accuracy: 19.3%
# Test Error:
#  Avg loss: 3.723627, Accuracy: 8.0%
#
# Epoch 112
# -------------------------------
# loss: 3.437741  [   32/  399]
# Train loss: 3.521687, Accuracy: 20.1%
# Test Error:
#  Avg loss: 3.786380, Accuracy: 6.0%
#
# Epoch 113
# -------------------------------
# loss: 3.542774  [   32/  399]
# Train loss: 3.485707, Accuracy: 18.8%
# Test Error:
#  Avg loss: 3.739912, Accuracy: 5.0%
#
# Epoch 114
# -------------------------------
# loss: 3.414293  [   32/  399]
# Train loss: 3.458422, Accuracy: 19.5%
# Test Error:
#  Avg loss: 3.881809, Accuracy: 7.0%
#
# Epoch 115
# -------------------------------
# loss: 3.269960  [   32/  399]
# Train loss: 3.442731, Accuracy: 18.5%
# Test Error:
#  Avg loss: 3.729347, Accuracy: 8.0%
#
# Epoch 116
# -------------------------------
# loss: 3.309984  [   32/  399]
# Train loss: 3.404384, Accuracy: 19.5%
# Test Error:
#  Avg loss: 3.682455, Accuracy: 6.0%
#
# Epoch 117
# -------------------------------
# loss: 3.313325  [   32/  399]
# Train loss: 3.355700, Accuracy: 19.0%
# Test Error:
#  Avg loss: 3.688062, Accuracy: 7.0%
#
# Epoch 118
# -------------------------------
# loss: 3.320904  [   32/  399]
# Train loss: 3.311058, Accuracy: 24.6%
# Test Error:
#  Avg loss: 3.712354, Accuracy: 7.0%
#
# Epoch 119
# -------------------------------
# loss: 3.362040  [   32/  399]
# Train loss: 3.268344, Accuracy: 20.6%
# Test Error:
#  Avg loss: 3.793108, Accuracy: 6.0%
#
# Epoch 120
# -------------------------------
# loss: 2.994084  [   32/  399]
# Train loss: 3.222443, Accuracy: 21.8%
# Test Error:
#  Avg loss: 3.697647, Accuracy: 3.0%
#
# Epoch 121
# -------------------------------
# loss: 3.252459  [   32/  399]
# Train loss: 3.169882, Accuracy: 25.1%
# Test Error:
#  Avg loss: 3.580608, Accuracy: 7.0%
#
# Epoch 122
# -------------------------------
# loss: 3.201220  [   32/  399]
# Train loss: 3.102919, Accuracy: 27.8%
# Test Error:
#  Avg loss: 3.602276, Accuracy: 4.0%
#
# Epoch 123
# -------------------------------
# loss: 2.906409  [   32/  399]
# Train loss: 3.062836, Accuracy: 26.1%
# Test Error:
#  Avg loss: 3.474734, Accuracy: 10.0%
#
# Epoch 124
# -------------------------------
# loss: 2.954026  [   32/  399]
# Train loss: 2.985036, Accuracy: 28.8%
# Test Error:
#  Avg loss: 3.430277, Accuracy: 9.0%
#
# Epoch 125
# -------------------------------
# loss: 2.973668  [   32/  399]
# Train loss: 2.886576, Accuracy: 29.8%
# Test Error:
#  Avg loss: 3.820046, Accuracy: 5.0%
#
# Epoch 126
# -------------------------------
# loss: 3.031129  [   32/  399]
# Train loss: 2.836825, Accuracy: 31.1%
# Test Error:
#  Avg loss: 4.006353, Accuracy: 2.0%
#
# Epoch 127
# -------------------------------
# loss: 2.963195  [   32/  399]
# Train loss: 2.826490, Accuracy: 27.8%
# Test Error:
#  Avg loss: 3.617378, Accuracy: 7.0%
#
# Epoch 128
# -------------------------------
# loss: 2.860361  [   32/  399]
# Train loss: 2.723545, Accuracy: 31.6%
# Test Error:
#  Avg loss: 3.405072, Accuracy: 10.0%
#
# Epoch 129
# -------------------------------
# loss: 2.781646  [   32/  399]
# Train loss: 2.675440, Accuracy: 31.1%
# Test Error:
#  Avg loss: 3.617590, Accuracy: 12.0%
#
# Epoch 130
# -------------------------------
# loss: 2.742997  [   32/  399]
# Train loss: 2.582446, Accuracy: 33.1%
# Test Error:
#  Avg loss: 3.494831, Accuracy: 13.0%
#
# Epoch 131
# -------------------------------
# loss: 2.608671  [   32/  399]
# Train loss: 2.454722, Accuracy: 36.1%
# Test Error:
#  Avg loss: 4.502288, Accuracy: 5.0%
#
# Epoch 132
# -------------------------------
# loss: 2.913740  [   32/  399]
# Train loss: 2.426823, Accuracy: 34.6%
# Test Error:
#  Avg loss: 3.479733, Accuracy: 10.0%
#
# Epoch 133
# -------------------------------
# loss: 2.763619  [   32/  399]
# Train loss: 2.299493, Accuracy: 42.4%
# Test Error:
#  Avg loss: 3.259356, Accuracy: 13.0%
#
# Epoch 134
# -------------------------------
# loss: 2.646614  [   32/  399]
# Train loss: 2.246995, Accuracy: 41.6%
# Test Error:
#  Avg loss: 3.197149, Accuracy: 21.0%
#
# Epoch 135
# -------------------------------
# loss: 2.424351  [   32/  399]
# Train loss: 2.232710, Accuracy: 39.1%
# Test Error:
#  Avg loss: 3.894797, Accuracy: 16.0%
#
# Epoch 136
# -------------------------------
# loss: 2.852098  [   32/  399]
# Train loss: 1.972963, Accuracy: 50.1%
# Test Error:
#  Avg loss: 3.689202, Accuracy: 13.0%
#
# Epoch 137
# -------------------------------
# loss: 2.346564  [   32/  399]
# Train loss: 2.049907, Accuracy: 44.6%
# Test Error:
#  Avg loss: 4.783239, Accuracy: 3.0%
#
# Epoch 138
# -------------------------------
# loss: 5.009897  [   32/  399]
# Train loss: 2.320174, Accuracy: 38.3%
# Test Error:
#  Avg loss: 2.867881, Accuracy: 23.0%
#
# Epoch 139
# -------------------------------
# loss: 1.828881  [   32/  399]
# Train loss: 2.150813, Accuracy: 38.6%
# Test Error:
#  Avg loss: 3.145087, Accuracy: 25.0%
#
# Epoch 140
# -------------------------------
# loss: 1.857141  [   32/  399]
# Train loss: 1.769627, Accuracy: 50.9%
# Test Error:
#  Avg loss: 3.385092, Accuracy: 23.0%
#
# Epoch 141
# -------------------------------
# loss: 1.911888  [   32/  399]
# Train loss: 1.767183, Accuracy: 49.6%
# Test Error:
#  Avg loss: 3.157930, Accuracy: 21.0%
#
# Epoch 142
# -------------------------------
# loss: 1.643369  [   32/  399]
# Train loss: 1.608158, Accuracy: 57.9%
# Test Error:
#  Avg loss: 3.481974, Accuracy: 22.0%
#
# Epoch 143
# -------------------------------
# loss: 2.000229  [   32/  399]
# Train loss: 1.463273, Accuracy: 59.4%
# Test Error:
#  Avg loss: 2.523684, Accuracy: 32.0%
#
# Epoch 144
# -------------------------------
# loss: 1.450693  [   32/  399]
# Train loss: 1.597414, Accuracy: 53.9%
# Test Error:
#  Avg loss: 2.909854, Accuracy: 21.0%
#
# Epoch 145
# -------------------------------
# loss: 2.498086  [   32/  399]
# Train loss: 1.559568, Accuracy: 59.1%
# Test Error:
#  Avg loss: 3.157205, Accuracy: 24.0%
#
# Epoch 146
# -------------------------------
# loss: 1.712920  [   32/  399]
# Train loss: 1.402498, Accuracy: 59.6%
# Test Error:
#  Avg loss: 3.868123, Accuracy: 21.0%
#
# Epoch 147
# -------------------------------
# loss: 1.851789  [   32/  399]
# Train loss: 1.403073, Accuracy: 61.2%
# Test Error:
#  Avg loss: 4.576245, Accuracy: 11.0%
#
# Epoch 148
# -------------------------------
# loss: 1.703208  [   32/  399]
# Train loss: 1.249554, Accuracy: 64.4%
# Test Error:
#  Avg loss: 3.459890, Accuracy: 25.0%
#
# Epoch 149
# -------------------------------
# loss: 1.402545  [   32/  399]
# Train loss: 1.139766, Accuracy: 70.4%
# Test Error:
#  Avg loss: 2.653974, Accuracy: 33.0%
#
# Epoch 150
# -------------------------------
# loss: 1.010168  [   32/  399]
# Train loss: 0.942785, Accuracy: 75.7%
# Test Error:
#  Avg loss: 3.077487, Accuracy: 35.0%
#
# Done!

# %%
plt.plot(range(1, epochs+1), train_accuracies, 'm' , label="Train Accuracy")
plt.plot(range(1, epochs+1), test_accuracies, label="Test Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training and Testing Accuracy over Epochs")
plt.legend()
plt.show()

# %%
plt.plot(train_losses, 'm', label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Test Loss over Epochs")
plt.legend()
plt.show()

# %%
model.eval()

wrong_preds = []

with torch.no_grad():
    for idx in range(len(test_set)):
        x, y = test_set[idx][0], test_set[idx][1]
        x = x.to(device)
        pred = model(x.unsqueeze(0))  # btch dim
        predicted_label = pred[0].argmax(0).item()

        if predicted_label != y:
            wrong_preds.append(idx)

len(wrong_preds)
# Out:
# 65

# %%
model.eval()
id = 8
idx = wrong_preds[id]
x, y = test_set[idx][0], test_set[idx][1]
plt.imshow(x.permute(1,2,0))
with torch.no_grad():
    x = x.to(device)
    pred = model(x.unsqueeze(0))
    # predicted, actual = classes[pred[0].argmax(0)], classes[y]
    predicted, actual = [pred[0].argmax(0)], [y]
    predicted = predicted[0].item()
    actual = actual[0].item()
    print(f'Predicted: "{predicted, labels_map[predicted]}", Actual: "{actual, labels_map[actual]}"')
# Out:
# Predicted: "(41, 'aeble_most: 34dkk')", Actual: "(42, 'appelsin_juice: 34dkk')"

# %%
model.eval()

correct_preds = []

with torch.no_grad():
    for idx in range(len(test_set)):
        x, y = test_set[idx][0], test_set[idx][1]
        x = x.to(device)
        pred = model(x.unsqueeze(0))  # batch dim
        predicted_label = pred[0].argmax(0).item()

        if predicted_label == y:
            correct_preds.append(idx)

len(correct_preds)
# Out:
# 35

# %%
model.eval()
id = 4
idx = correct_preds[id]
x, y = test_set[idx][0], test_set[idx][1]
plt.imshow(x.permute(1,2,0))
with torch.no_grad():
    x = x.to(device)
    pred = model(x.unsqueeze(0))
    # predicted, actual = classes[pred[0].argmax(0)], classes[y]
    predicted, actual = [pred[0].argmax(0)], [y]
    predicted = predicted[0].item()
    actual = actual[0].item()
    print(f'Predicted: "{predicted, labels_map[predicted]}", Actual: "{actual, labels_map[actual]}"')
# Out:
# Predicted: "(14, 's_smith_chocolade: 55dkk')", Actual: "(14, 's_smith_chocolade: 55dkk')"
